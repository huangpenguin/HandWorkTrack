# %%
e2f={'dog':'chien','cat':'chat','walrus':'morse'}
e2f
# Out:
# {'dog': 'chien', 'cat': 'chat', 'walrus': 'morse'}

# %%
e2f['walrus']
# Out:
# 'morse'

# %%
f2e={}
for eng,fra in e2f.items():
    f2e[fra]=eng
f2e
# Out:
# {'chien': 'dog', 'chat': 'cat', 'morse': 'walrus'}

# %%
f2e['chien']
# Out:
# 'dog'

# %%
set(e2f.keys())
# Out:
# {'cat', 'dog', 'walrus'}

# %%
list_cat=['Henri','Grumpy','Lucy']
dict_animal={'cats':list_cat,'octopi':{},'emus':{}}
life={'animals':dict_animal,'plants':{},'other':{}}

# %%
life.keys()
# Out:
# dict_keys(['animals', 'plants', 'other'])

# %%
life['animals'].keys()
# Out:
# dict_keys(['cat', 'octopi', 'emus'])

# %%
life['animals']['cats']
# Out:
# ['Henri', 'Grumpy', 'Lucy']

# %%
squares={keys:keys**2 for keys in range(10)}
squares
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
set={odds for odds in range(10) if odds%2 == 1}
set
# Out:
# {1, 3, 5, 7, 9}

# %%
keys=('optimist','pessimist','troll')
values=('The glass is half full',
        'The glass is half empty',
        'How did you get a glass?')
dict(zip(keys,values))#zip iterator
# Out:
# {'optimist': 'The glass is half full',
#  'pessimist': 'The glass is half empty',
#  'troll': 'How did you get a glass?'}

# %%
titles=['Creature of a Habit',
        'Crewel Fate',
        'Sharks On a Planed']
plots=['A nun turns into a monster',
       'A haunted yarn shop',
       'Check your exits']
movies=dict(zip(titles,plots))
movies
# Out:
# {'Creature of a Habit': 'A nun turns into a monster',
#  'Crewel Fate': 'A haunted yarn shop',
#  'Sharks On a Planed': 'Check your exits'}
