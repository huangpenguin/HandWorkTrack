# %%
import os 
with os.scandir('.') as it:
    entries=[entry.name for entry in it]
entries
# Out:
# ['task_section14.ipynb', 'task_section8.ipynb']

# %%
import os 
with os.scandir('..') as it:
    entries=[entry.name for entry in it]
entries
# Out:
# ['.venv',
#  'data',
#  'notebook',
#  'output',
#  'pyproject.toml',
#  'readme.md',
#  'requirements.txt',
#  'script',
#  'src',
#  'tests']

# %%
test1='This is the test of the emergency text system'

with open('test.txt','w') as f:
    f.write(test1)

# %%
with open ('test.txt','r')as f:
    test2=f.read()
test1==test2
# Out:
# True
